# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('./train.csv', header=None)
test_df = pd.read_csv('./test.csv', header=None)
y = pd.read_csv('./trainLabels.csv', header=None)
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.299403 -1.226624  1.498425 -1.176150  5.289853  0.208297  2.404498
# 1 -1.174176  0.332157  0.949919 -1.285328  2.199061 -0.151268 -0.427039
# 2  1.192222 -0.414371  0.067054 -2.233568  3.658881  0.089007  0.203439
# 3  1.573270 -0.580318 -0.866332 -0.603812  3.125716  0.870321 -0.161992
# 4 -0.613071 -0.644204  1.112558 -0.032397  3.490142 -0.011935  1.443521
#
#          7         8         9   ...        30        31        32        33  \
# 0  1.594506 -0.051608  0.663234  ... -0.850465 -0.622990 -1.833057  0.293024
# 1  2.619246 -0.765884 -0.093780  ... -0.819750  0.012037  2.038836  0.468579
# 2 -4.219054 -1.184919 -1.240310  ... -0.604501  0.750054 -3.360521  0.856988
# 3  4.499666  1.038741 -1.092716  ...  1.022959  1.275598 -3.480110 -1.065252
# 4 -4.290282 -1.761308  0.807652  ...  0.513906 -1.803473  0.518579 -0.205029
#
#          34        35        36        37        38        39
# ...

# %%
X_train, X_valid, y_train, y_valid = train_test_split(df, y, test_size=0.3, random_state=0)
y_train = np.ravel(y_train)
y_valid = np.ravel(y_valid)

# %%
#Checking data shape
print('train shape:', X_train.shape)
print('val shape:', X_valid.shape)
print('test shape:', X_test.shape)
# Out:
# train shape: (700, 40)
# val shape: (300, 40)
# test shape: (9000, 40)

# %%
# We scaled our data using MinMaxScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
svc = GradientBoostingClassifier(loss="deviance",max_depth= 3)
svc.fit(X_train_scaled,y_train)
svc.predict(X_valid_scaled)
d = svc.score(X_valid_scaled,y_valid)
print("scorce :", d)
# Out:
# scorce : 0.8866666666666667

# %%
submission = pd.DataFrame(svc.predict(test_df))
submission.columns = ['Solution']
submission['Id'] = np.arange(1,submission.shape[0]+1)
submission = submission[['Id', 'Solution']]

# %%
submission.to_csv('submission_with_scaling.csv', index=False)
