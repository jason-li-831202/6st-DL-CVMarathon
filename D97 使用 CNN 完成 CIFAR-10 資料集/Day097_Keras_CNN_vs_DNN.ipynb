# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os
# Out:
# Using TensorFlow backend.
# C:\Users\zuoo5\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\zuoo5\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\zuoo5\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\zuoo5\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\zuoo5\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\zuoo5\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# 由於 DNN 只能輸入一維的資料，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32*32*3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 24s 482us/step - loss: 2.2218 - acc: 0.2489 - val_loss: 1.8383 - val_acc: 0.3300
# Epoch 2/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.8668 - acc: 0.3249 - val_loss: 1.7780 - val_acc: 0.3595
# Epoch 3/10
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.7969 - acc: 0.3505 - val_loss: 1.6936 - val_acc: 0.4084
# Epoch 4/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.7506 - acc: 0.3697 - val_loss: 1.6810 - val_acc: 0.3982
# Epoch 5/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.7158 - acc: 0.3834 - val_loss: 1.6102 - val_acc: 0.4280
# Epoch 6/10
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.6923 - acc: 0.3916 - val_loss: 1.6494 - val_acc: 0.4204
# Epoch 7/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.6685 - acc: 0.3997 - val_loss: 1.6370 - val_acc: 0.4204
# Epoch 8/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.6481 - acc: 0.4104 - val_loss: 1.5764 - val_acc: 0.4478
# Epoch 9/10
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.6371 - acc: 0.4124 - val_loss: 1.5704 - val_acc: 0.4496
# Epoch 10/10
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.6275 - acc: 0.4203 - val_loss: 1.5604 - val_acc: 0.4479
# Test loss: 1.560353709411621
# Test accuracy: 0.4479

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
## 超參數設定
import itertools
FILTER_SIZE = [2, 3]

# %%
for i, (conv_filter_size, pool_filter_size) in enumerate(itertools.product(FILTER_SIZE, FILTER_SIZE)):
    model = Sequential()
    model.add(Conv2D(32, (conv_filter_size, conv_filter_size), padding='same',
                     input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (conv_filter_size, conv_filter_size)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(pool_filter_size, pool_filter_size)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (conv_filter_size, conv_filter_size), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (conv_filter_size, conv_filter_size)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(pool_filter_size, pool_filter_size)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    model.summary()

    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=1,
                        validation_data=(x_test, y_test))
    score = model.evaluate(x_test, y_test, verbose=0)
    
    exp_name_tag = "conv-%s-pool-%s" % (str(conv_filter_size), str(pool_filter_size))
    print('超參數:', exp_name_tag)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# activation_13 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 31, 31, 32)        4128
# _________________________________________________________________
# activation_14 (Activation)   (None, 31, 31, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 15, 64)        8256
# _________________________________________________________________
# activation_15 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 64)        16448
# _________________________________________________________________
# activation_16 (Activation)   (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# activation_17 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_18 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,640,522
# Trainable params: 1,640,522
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 17s 345us/step - loss: 1.6981 - acc: 0.3869 - val_loss: 1.3736 - val_acc: 0.4966
# Epoch 2/10
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.2801 - acc: 0.5458 - val_loss: 1.0616 - val_acc: 0.6251
# Epoch 3/10
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.0890 - acc: 0.6144 - val_loss: 0.9653 - val_acc: 0.6582
# Epoch 4/10
# 50000/50000 [==============================] - 16s 322us/step - loss: 0.9784 - acc: 0.6560 - val_loss: 0.9578 - val_acc: 0.6703
# Epoch 5/10
# 50000/50000 [==============================] - 16s 322us/step - loss: 0.8931 - acc: 0.6873 - val_loss: 0.8327 - val_acc: 0.7059
# Epoch 6/10
# 50000/50000 [==============================] - 16s 320us/step - loss: 0.8341 - acc: 0.7085 - val_loss: 0.8206 - val_acc: 0.7111
# Epoch 7/10
# 50000/50000 [==============================] - 16s 322us/step - loss: 0.7860 - acc: 0.7257 - val_loss: 0.8128 - val_acc: 0.7203
# Epoch 8/10
# 50000/50000 [==============================] - 16s 322us/step - loss: 0.7444 - acc: 0.7423 - val_loss: 0.7487 - val_acc: 0.7380
# Epoch 9/10
# 50000/50000 [==============================] - 16s 322us/step - loss: 0.7160 - acc: 0.7521 - val_loss: 0.7775 - val_acc: 0.7251
# Epoch 10/10
# 50000/50000 [==============================] - 16s 321us/step - loss: 0.6953 - acc: 0.7604 - val_loss: 0.7296 - val_acc: 0.7498
# 超參數: conv-2-pool-2
# Test loss: 0.7295536085128784
# Test accuracy: 0.7498
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        416
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 31, 31, 32)        4128
# _________________________________________________________________
# activation_20 (Activation)   (None, 31, 31, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 10, 10, 64)        8256
# _________________________________________________________________
# activation_21 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 9, 9, 64)          16448
# _________________________________________________________________
# activation_22 (Activation)   (None, 9, 9, 64)          0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               295424
# _________________________________________________________________
# activation_23 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_24 (Activation)   (None, 10)                0
# =================================================================
# Total params: 329,802
# Trainable params: 329,802
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 13s 256us/step - loss: 1.8177 - acc: 0.3348 - val_loss: 1.4674 - val_acc: 0.4738
# Epoch 2/10
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.4566 - acc: 0.4711 - val_loss: 1.3082 - val_acc: 0.5377
# Epoch 3/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 1.2735 - acc: 0.5427 - val_loss: 1.1146 - val_acc: 0.6030
# Epoch 4/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 1.1518 - acc: 0.5885 - val_loss: 1.0014 - val_acc: 0.6488
# Epoch 5/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 1.0674 - acc: 0.6219 - val_loss: 0.9321 - val_acc: 0.6751
# Epoch 6/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 1.0025 - acc: 0.6446 - val_loss: 0.9116 - val_acc: 0.6737
# Epoch 7/10
# 50000/50000 [==============================] - 12s 243us/step - loss: 0.9544 - acc: 0.6638 - val_loss: 0.8661 - val_acc: 0.6965
# Epoch 8/10
# 50000/50000 [==============================] - 12s 242us/step - loss: 0.9142 - acc: 0.6772 - val_loss: 0.8007 - val_acc: 0.7220
# Epoch 9/10
# 50000/50000 [==============================] - 12s 240us/step - loss: 0.8827 - acc: 0.6899 - val_loss: 0.8327 - val_acc: 0.7133
# Epoch 10/10
# 50000/50000 [==============================] - 12s 242us/step - loss: 0.8512 - acc: 0.7013 - val_loss: 0.7823 - val_acc: 0.7273
# 超參數: conv-2-pool-3
# Test loss: 0.7822982307434082
# Test accuracy: 0.7273
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_25 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_26 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_27 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_28 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_29 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_30 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.7431 - acc: 0.3725 - val_loss: 1.3162 - val_acc: 0.5250
# Epoch 2/10
# 50000/50000 [==============================] - 18s 370us/step - loss: 1.3194 - acc: 0.5341 - val_loss: 1.1721 - val_acc: 0.5885
# Epoch 3/10
# 50000/50000 [==============================] - 18s 367us/step - loss: 1.1103 - acc: 0.6124 - val_loss: 0.9620 - val_acc: 0.6668
# Epoch 4/10
# 50000/50000 [==============================] - 18s 370us/step - loss: 0.9658 - acc: 0.6621 - val_loss: 0.8728 - val_acc: 0.6976
# Epoch 5/10
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.8777 - acc: 0.6950 - val_loss: 0.8423 - val_acc: 0.7145
# Epoch 6/10
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.8167 - acc: 0.7168 - val_loss: 0.7875 - val_acc: 0.7280
# Epoch 7/10
# 50000/50000 [==============================] - 18s 359us/step - loss: 0.7581 - acc: 0.7372 - val_loss: 0.7594 - val_acc: 0.7387
# Epoch 8/10
# 50000/50000 [==============================] - 18s 355us/step - loss: 0.7174 - acc: 0.7523 - val_loss: 0.7716 - val_acc: 0.7381
# Epoch 9/10
# 50000/50000 [==============================] - 18s 366us/step - loss: 0.6895 - acc: 0.7613 - val_loss: 0.6868 - val_acc: 0.7604
# Epoch 10/10
# 50000/50000 [==============================] - 18s 368us/step - loss: 0.6592 - acc: 0.7713 - val_loss: 0.7154 - val_acc: 0.7651
# 超參數: conv-3-pool-2
# Test loss: 0.7154090565681458
# Test accuracy: 0.7651
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_31 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_32 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 10, 32)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# activation_33 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# activation_34 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               131584
# _________________________________________________________________
# activation_35 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_36 (Activation)   (None, 10)                0
# =================================================================
# Total params: 202,282
# Trainable params: 202,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.8733 - acc: 0.3052 - val_loss: 1.7957 - val_acc: 0.3852
# Epoch 2/10
# 50000/50000 [==============================] - 14s 278us/step - loss: 1.4961 - acc: 0.4569 - val_loss: 1.4357 - val_acc: 0.4871
# Epoch 3/10
# 50000/50000 [==============================] - 14s 277us/step - loss: 1.3149 - acc: 0.5316 - val_loss: 1.1612 - val_acc: 0.5870
# Epoch 4/10
# 50000/50000 [==============================] - 14s 277us/step - loss: 1.1937 - acc: 0.5808 - val_loss: 1.0282 - val_acc: 0.6392
# Epoch 5/10
# 50000/50000 [==============================] - 14s 277us/step - loss: 1.1017 - acc: 0.6096 - val_loss: 0.9571 - val_acc: 0.6672
# Epoch 6/10
# 50000/50000 [==============================] - 14s 277us/step - loss: 1.0402 - acc: 0.6364 - val_loss: 0.9139 - val_acc: 0.6887
# Epoch 7/10
# 50000/50000 [==============================] - 14s 278us/step - loss: 0.9825 - acc: 0.6543 - val_loss: 0.9367 - val_acc: 0.6772
# Epoch 8/10
# 50000/50000 [==============================] - 14s 278us/step - loss: 0.9387 - acc: 0.6711 - val_loss: 0.9013 - val_acc: 0.6900
# Epoch 9/10
# 50000/50000 [==============================] - 14s 278us/step - loss: 0.9021 - acc: 0.6838 - val_loss: 0.8710 - val_acc: 0.6995
# Epoch 10/10
# 50000/50000 [==============================] - 14s 278us/step - loss: 0.8688 - acc: 0.6965 - val_loss: 0.7895 - val_acc: 0.7329
# 超參數: conv-3-pool-3
# Test loss: 0.7895169041633606
# Test accuracy: 0.7329

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?

# %% [markdown]
# 以此例來看，當conv_filter_size = 3x3，pool_filter_size= 2x2時，測試集準確率可達0.7651(為最高)。
# 當pool_filter_size採用3x3時，參數量皆會大幅下降。而採用2x2則與原先的DNN模型數量差不多。
